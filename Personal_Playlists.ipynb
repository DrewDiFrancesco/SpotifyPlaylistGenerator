# %%
import joblib
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import os
import matplotlib.pyplot as plt


wd = os.getcwd()
head, tail = wd.rsplit('\\', 1)
head = head.replace('\\', '/')

try:
    from configparser import ConfigParser
except ImportError:
    from ConfigParser import ConfigParser

config = ConfigParser()
config.read(head + '/config.ini')

client_id = config['DEFAULT']['client_id']
client_secret = config['DEFAULT']['client_secret']
redirect_uri = config['DEFAULT']['redirect_uri']
username = config['DEFAULT']['username']

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
scope = 'user-library-read'
token = util.prompt_for_user_token(username, scope, client_id=client_id, client_secret=client_secret, redirect_uri=redirect_uri)
sp = spotipy.Spotify(auth=token)

# %%
def get_saved_tracks(limit = 50, offset = 0):
    saved_tracks = [ ]
    
    # get initial list of tracks to determine length
    saved_tracks_obj = sp.current_user_saved_tracks(limit = limit, offset = offset)
    num_saved_tracks = saved_tracks_obj['total']
    
    # loop through to get all saved tracked
    while (offset < num_saved_tracks):
        saved_tracks_obj = sp.current_user_saved_tracks(limit = limit, offset = offset)
        
        # add track information to running list
        for track_obj in saved_tracks_obj['items']:
            saved_tracks.append({
                'name': track_obj['track']['name'],
                'artists': ', '.join([artist['name'] for artist in track_obj['track']['artists']]),
                'track_id': track_obj['track']['id']
            })
            
        offset += limit
        
    return saved_tracks

def get_audio_features(track_ids):
    saved_tracks_audiofeat = [ ]
    
    # iterate through track_ids in groups of 50
    for ix in range(0,len(track_ids),50):
        audio_feats = sp.audio_features(track_ids[ix:ix+50])
        saved_tracks_audiofeat += audio_feats
        
    return saved_tracks_audiofeat

def save_cluster_tracks_to_playlist(playlist_name, track_ids):
    # get all of the users playlists
    all_playlists = get_all_user_playlists()
    
    # check if playlist already exists
    if (playlist_name not in [playlist['name'] for playlist in all_playlists]):
        playlist = sp.user_playlist_create(user = user_id, name = playlist_name, public = True)
    else:
        playlist_id = [playlist['id'] for playlist in all_playlists if playlist['name'] == playlist_name][0]
        playlist = sp.user_playlist(user = user_id, playlist_id = playlist_id)

    # remove any existing tracks in playlist
    while (playlist['tracks']['total'] > 0):
        sp.user_playlist_remove_all_occurrences_of_tracks(user_id, playlist['id'], \
                                                          tracks = [track['track']['id'] for track in \
                                                                    playlist['tracks']['items']])
        playlist = sp.user_playlist(user = user_id, playlist_id = playlist_id)

    # add tracks from cluster
    sp.user_playlist_add_tracks(user_id, playlist_id = playlist['id'], tracks = track_ids)
    
def get_all_user_playlists(playlist_limit = 50, playlist_offset = 0):
    # get initial list of users playlists (first n = playlist_limit), determine total number of playlists
    playlists_obj = sp.user_playlists(user_id, limit = playlist_limit, offset = playlist_offset)
    num_playlists = playlists_obj['total']

    # start accumulating playlist names and ids
    all_playlists = [{'name': playlist['name'], 'id': playlist['id']} for playlist in playlists_obj['items']]
    playlist_offset += playlist_limit

    # continue accumulating through all playlists
    while (playlist_offset < num_playlists):
        playlists_obj = sp.user_playlists(user_id, limit = playlist_limit, offset = playlist_offset)
        all_playlists += [{'name': playlist['name'], 'id': playlist['id']} for playlist in playlists_obj['items']]
        playlist_offset += playlist_limit
        
    return(all_playlists)

# %%
FEATURE_KEYS = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','duration_ms','time_signature']

saved_tracks    = get_saved_tracks()
saved_tracks_df = pd.DataFrame(saved_tracks)

# get audio features for saved songs
saved_tracks_audiofeat    = get_audio_features(track_ids = list(saved_tracks_df['track_id']))
saved_tracks_audiofeat_df = pd.DataFrame(saved_tracks_audiofeat).drop(['analysis_url', 'track_href', \
                                                                       'type', 'uri'], axis = 1)

# merge audio features onto tracks df
saved_tracks_plus_df = saved_tracks_df.merge(saved_tracks_audiofeat_df, how = 'left', \
                                             left_on = 'track_id', right_on = 'id').drop('id', axis = 1)

# %%
scaler = StandardScaler()
norm_d = scaler.fit_transform(saved_tracks_plus_df[FEATURE_KEYS])
norm_d = pd.DataFrame(norm_d, columns = FEATURE_KEYS)
norm_d['name'] = saved_tracks_plus_df['name']
norm_d['artists'] = saved_tracks_plus_df['artists']

# %%
loaded_model = joblib.load('webapp/model.sav')

# %%
norm_d['cluster'] = loaded_model.predict(norm_d[FEATURE_KEYS]) + 1

# %%
norm_d[norm_d['cluster']==14]
# Out:
#       danceability    energy       key  loudness      mode  speechiness  \
# 3         0.297719 -0.966591  0.759389 -0.558074  0.761673    -0.634645
# 22        0.291034 -1.388783  1.601805 -0.559438  0.761673    -0.700191
# 24       -0.812032  0.328133  0.759389 -2.094182  0.761673     0.315761
# 103      -0.357435  0.193032  0.197778  0.465316  0.761673    -0.120583
# 113      -0.297268  0.187403  1.601805  0.490901  0.761673    -0.593446
# ...            ...       ...       ...       ...       ...          ...
# 1681     -1.246574 -1.034141  1.040194 -0.272889  0.761673    -0.721727
# 1695      2.055940 -0.994737  0.197778 -0.827225  0.761673    -0.291001
# 1712     -0.196989 -1.152355  1.321000 -0.009196  0.761673    -0.325646
# 1726      0.083791  0.660258  0.759389  1.182030  0.761673    -0.612173
# 1734      0.197440  0.592707  0.759389 -0.150424  0.761673    -0.615918
#
#       acousticness  instrumentalness  liveness   valence     tempo  \
# 3        -0.822051          1.280063 -0.543152 -0.057972  0.620565
# 22        0.589640         -0.485218 -0.521376 -1.117132 -1.552069
# 24        0.408847          1.221994 -0.617191 -0.898439 -1.051497
# 103      -0.777606         -0.485250 -0.745670 -0.255225 -0.843065
# 113      -0.767059         -0.271171 -0.274579 -0.915591  0.770236
# ...            ...               ...       ...       ...       ...
# 1681      0.909794         -0.441122 -0.618643 -1.104267 -0.661545
# 1695     -0.800205         -0.483621 -0.683971 -0.426748 -0.052989
# 1712     -0.780996         -0.485255 -0.612110 -1.160013  0.377783
# 1726     -0.923295         -0.485239 -1.054167 -0.791237 -0.086638
# 1734     -0.768566         -0.484724 -0.093110 -0.263801 -0.617991
#
#       duration_ms  time_signature                             name  \
# 3       -0.258590        0.145564                          Twinkle
# 22      -0.132874        0.145564  She Don't Wear the Same Clothes
# 24      -0.338165        0.145564                       Satellites
# 103     -1.072904        0.145564                     Far Rockaway
# 113     -1.869371        0.145564                          Formula
# ...           ...             ...                              ...
# 1681     0.714873        0.145564                      Dory Previn
# 1695     0.206508        0.145564                       Down Below
# 1712     0.165031        0.145564                 Scott and Ramona
# 1726     0.411767        0.145564                      Hollow Life
# 1734     0.449441        0.145564          Stay (feat. Maty Noyes)
#
#                artists  cluster
# 3               Hether       14
# 22             Molokai       14
# 24               faang       14
# 103             KAMAUU       14
# 113           Labrinth       14
# ...                ...      ...
# 1681    Camera Obscura       14
# 1695       Roddy Ricch       14
# 1712      Lil Uzi Vert       14
# 1726      Coast Modern       14
# 1734  Kygo, Maty Noyes       14
#
# [138 rows x 16 columns]

# %%
songs = norm_d[['name','artists','cluster']]

# %%
grouped = songs.groupby(['cluster'], as_index=False)['artists'].head()
grouped
# Out:
# 0                    Moi Je, Petit Biscuit
# 1                  callmestevieray, Melkin
# 2                       Felly, Arden Jones
# 3                                   Hether
# 4                                    Healy
#                        ...
# 638                                  Crumb
# 1147                       Duffle Bag Buru
# 1210                                  Teho
# 1363                Carbon Based Lifeforms
# 1565    Circles Around The Sun, Neal Casal
# Name: artists, Length: 100, dtype: object

# %%
playlist_dict
# Out:
# {(1, 'ANNA'): ['Impression - Original Mix'],
#  (1, 'Ante Perry'): ['Daft Perry - Original'],
#  (1, 'Bassnectar'): ['Timestretch'],
#  (1, 'Berhana'): ['California'],
#  (1, 'Blood Cultures'): ['Flowers for All Occasions'],
#  (1, 'Boris Brejcha'): ['Purple Noise'],
#  (1, 'COIN'): ['Malibu 1992'],
#  (1, 'Cherub'): ['Doses & Mimosas'],
#  (1, 'Creedence Clearwater Revival'): ['I Heard It Through The Grapevine'],
#  (1, 'Current Joys'): ['A Different Age', 'My Motorcycle'],
#  (1, 'Deal Casino'): ['bangbangbang'],
#  (1, 'Derek & The Dominos, Duane Allman'): ['Layla'],
#  (1, 'GHOST DATA'): ['Angelic Layer'],
#  (1, 'Gary Clark Jr.'): ['When My Train Pulls In'],
#  (1, 'Getter, Joji'): ['On My Way Out'],
#  (1, 'Jaden'): ['Ninety'],
#  (1, 'Joyhauser'): ['C166W'],
#  (1, 'Kanye West'): ['Jail', 'Jesus Lord'],
#  (1, 'Kanye West, Pusha T'): ['Runaway'],
#  (1, 'King Gizzard & The Lizard Wizard'): ['Rattlesnake'],
#  (1, 'Lena Raine'): ['Resurrections'],
#  (1, 'Lil Wayne'): ['Let It All Work Out'],
#  (1, 'Lynyrd Skynyrd'): ['Free Bird'],
#  (1, 'MARTIN K4RMA, Salvatore Mediana'): ['Darkness'],
#  (1, 'Novacane'): ['Monkey Bread'],
#  (1, 'ODESZA, Bettye LaVette'): ['The Last Goodbye (feat. Bettye LaVette)',
#   'The Last Goodbye (feat. Bettye LaVette)'],
#  (1, 'Peach Pit'): ["Tommy's Party"],
#  (1, 'Pink Floyd'): ['Comfortably Numb'],
#  (1, 'Porter Robinson'): ['Look at the Sky'],
#  (1, 'Pretty Lights'): ['Hot Like Sauce'],
#  (1, 'Rennie Foster, Edu Imbernon'): ["Devil's Water - Edu Imbernon Remix"],
#  (1, 'RÜFÜS DU SOL'): ['Alive', 'Underwater', 'Innerbloom'],
#  (1, 'Silversun Pickups'): ['Lazy Eye'],
#  (1, 'Soccer Mommy'): ['yellow is the color of her eyes'],
#  (1,
#   'Spillage Village, EARTHGANG, JID, Jurdan Bryant, Mereba, Hollywood JB'): ['End Of Daze (with EARTHGANG & JID feat. Jurdan Bryant, Mereba & Hollywood JB)'],
#  (1, 'TOLEDO'): ['Some Samurai', 'Some Samurai'],
#  (1, 'Tame Impala'): ['Eventually'],
#  (1, 'The Doors'): ['L.A. Woman'],
#  (1, 'The Rolling Stones'): ["Can't You Hear Me Knocking - 2009 Mix",
#   'Sympathy For The Devil - 50th Anniversary Edition'],
#  (1, 'The Toxic Avenger'): ['My Only Chance'],
#  (1, 'Vacations, Sarah Sykes, Craterface'): ['Panache'],
#  (1, 'Widespread Panic'): ['Cotton Was King', 'Conrad', 'Greta', 'Honky Red'],
#  (1, 'Wiz Khalifa, Ty Dolla $ign'): ['Lit (feat. Ty Dolla $ign)'],
#  (2, 'Arlie'): ['didya think'],
#  (2, 'BONNIE X CLYDE'): ['OURS'],
#  (2, 'Biskwiq'): ['A First Date'],
#  (2, 'Blue Öyster Cult'): ['Godzilla'],
#  (2, 'Carlie Hanson, MASN'): ['Gucci Knife (feat. MASN)'],
#  (2, "Chris Patrick, Deante' Hitchcock"): ['Typical Shit'],
#  (2, 'Chuck Sutton'): ['133 (Ode to Freshman)'],
#  (2, 'DWLLRS'): ['Float Through The Ceiling'],
#  (2, 'Document One'): ['LSD'],
#  (2, 'Flume'): ['Jewel'],
#  (2, 'Flume, Reo Cragun'): ['Friends'],
#  (2, 'Freshie'): ['Double Back'],
#  (2, 'Future'): ['Look Ahead'],
#  (2, 'Gentlemens Club, Que Fieri'): ['Money Talk'],
#  (2, 'IDK, Westside Gunn, MF DOOM, Jay Electronica'): ['Red'],
#  (2, 'ILLENIUM, Joni Fatora'): ['Fortress'],
#  (2, "ILLENIUM, Liam O'Donnell"): ['It’s All on U'],
#  (2, 'JAWNY'): ['Sabotage'],
#  (2, 'Joey Bada$$'): ['Love Is Only a Feeling'],
#  (2, 'Kasbo'): ['The Making of a Paracosm'],
#  (2, 'Kendrick Lamar'): ['Ignorance Is Bliss'],
#  (2, 'LORD$OFDOGTOWN'): ['COMMA$'],
#  (2,
#   'Lil Yachty, Tierra Whack, A$AP Rocky, Tyler, The Creator'): ['T.D (Lil Yachty & Tierra Whack feat. A$AP Rocky & Tyler, The Creator)'],
#  (2, 'Literature'): ['New Jacket'],
#  (2,
#   'Louis The Child, NoMBe, Big Gigantic'): ['Save Me From Myself (with NoMBe & Big Gigantic)'],
#  (2, 'Lunar Vacation'): ['Shrug'],
#  (2, 'Mac Miller'): ['Angel Dust'],
#  (2, 'Madvillain, Madlib, MF DOOM'): ['Great Day',
#   'Money Folder',
#   'Meat Grinder'],
#  (2, 'Marshmello, Lil Peep'): ['Spotlight'],
#  (2, 'Mos Def'): ['Hip Hop'],
#  (2, 'Nas'): ['Street Dreams'],
#  (2,
#   'Nas, Big Sean, Don Toliver'): ['Replace Me (feat. Big Sean & Don Toliver)'],
#  (2, 'Nas, Hit-Boy'): ['Ultra Black (feat. Hit-Boy)'],
#  (2, 'ODESZA'): ['Meridian'],
#  (2, 'Peace'): ['O You'],
#  (2, 'Peach Tree Rascals'): ["Things Won't Go My Way"],
#  (2, 'Peacock Affect, E I S U'): ['Who Cares If You Exist - Remix'],
#  (2, 'Pink Floyd'): ['Wish You Were Here'],
#  (2, 'Playboi Carti'): ['ILoveUIHateU'],
#  (2,
#   'Portugal. The Man, Richie Havens, Son Little'): ['Number One (feat. Richie Havens & Son Little)'],
#  (2, 'Rainbow Kitten Surprise'): ["It's Called: Freefall"],
#  (2, 'Rakim, Clark Kent'): ['Finest Ones'],
#  (2, 'Run The Jewels, El-P, Killer Mike'): ['holy calamafuck'],
#  (2,
#   'Run The Jewels, El-P, Killer Mike, DJ Premier, Greg Nice, Lil Wayne'): ['ooh la la (feat. Lil Wayne, Greg Nice & DJ Premier) - Remix'],
#  (2, 'SAIAH, RIZ LA VIE'): ['LAZLO'],
#  (2, 'STEPHAN, Current Blue'): ['Daytrip'],
#  (2, 'Sam Silver, A$AP Twelvyy, pineappleCITI'): ['Little After Sunset'],
#  (2, 'San Holo, Caspian'): ['surface'],
#  (2, 'Sipper'): ['Dance In Room Song'],
#  (2, 'Skrillex, Habstrakt'): ['Chicken Soup'],
#  (2, 'Stephen'): ['Crossfire'],
#  (2, 'Still Woozy'): ['Get By'],
#  (2, 'The Knocks, Mat Zo'): ['Get Happy (feat. Mat Zo)'],
#  (2, 'The Pharcyde'): ['Return Of The B-Boy'],
#  (2, 'Tommy Ice, Powfu'): ['hurt myself'],
#  (2, 'Trent the HOOLiGAN'): ['Bullet'],
#  (2, 'Trippie Redd'): ['Love Sick'],
#  (2,
#   'Tyler, The Creator, YoungBoy Never Broke Again, Ty Dolla $ign'): ['WUSYANAME (feat. Youngboy Never Broke Again & Ty Dolla $ign)'],
#  (2, 'Verzache'): ['Life Inside'],
#  (2, 'Viktor Vaughn, MF DOOM'): ['Vaudeville Villain'],
#  (2, 'andy polk'): ['toyota ae86'],
#  (2, 'boy pablo'): ['leave me alone!'],
#  (2, 'dark cat, juu, Cinders'): ['BUBBLE TEA'],
#  (2, 'fanclubwallet'): ['Car Crash in G Major', 'Car Crash in G Major'],
#  (2, 'fusq'): ['Perfume!'],
#  (2, 'j^p^n'): ['Loveyou'],
#  (2, 'seeyousoon'): ['Steamy'],
#  (2, 'spill tab'): ['PISTOLWHIP'],
#  (2, 'whiterosemoxie, midwxst'): ['ITACHI (feat. midwxst)'],
#  (3, 'Duster'): ['Stars Will Fall'],
#  (3, 'Fog Lake'): ['Extension Cord'],
#  (3, 'Fred again..'): ['Winnie (rosslyn crescent)'],
#  (3, 'Free The Birds'): ['Do U Miss All The'],
#  (3, 'Haux'): ['Calico'],
#  (3, 'Hysterla'): ['the pictures on my phone are all of you'],
#  (3, 'Joji, D33J, Shlohmo'): ['WHY AM I STILL IN LA (feat. Shlohmo & D33J)'],
#  (3, 'Liana Flores'): ['rises the moon'],
#  (3, 'Mac DeMarco'): ['New You'],
#  (3, 'Montell Fish'): ['Darling'],
#  (3, 'Patrick Watson'): ['Je te laisserai des mots'],
#  (3, 'Strawberry Milk Cult'): ['Portland'],
#  (3, 'Teen Suicide'): ['no, the moon', 'no, the moon'],
#  (3, 'Tennyson'): ['Virgil'],
#  (3, 'beabadoobee'): ['Coffee'],
#  (3, 'dandelion hands'): ['Lonely', 'How To Never Stop Being Sad'],
#  (3, 'salvia palth'): ['i was all over her'],
#  (4, '$ummer$, Surf Curse'): ['freaks - $ummer$ Remix'],
#  (4, 'A-1'): ['Invisible Man'],
#  (4, 'Adrianne Lenker'): ['anything'],
#  (4, 'Alice Cooper'): ["I'm Eighteen"],
#  (4,
#   'American Pleasure Club, Teen Suicide'): ['all the lonely nights in your life'],
#  (4, 'Andy Shauf'): ['Early to the Party'],
#  (4, 'Angelo De Augustine'): ['Santa Barbara'],
#  (4, 'Arden Jones'): ['indifferent'],
#  (4, 'BETWEEN FRIENDS'): ['more'],
#  (4, 'Beach Fossils'): ['Agony'],
#  (4, 'Bedside Kites'): ['Memories of Opal',
#   'A Sad Song About a Girl I No Longer Know'],
#  (4, 'Billie Eilish'): ['Your Power'],
#  (4, 'Billie Eilish, Astronomyy'): ['Ocean Eyes (Astronomyy Edit)'],
#  (4, 'Current Joys'): ['Nervous',
#   'My Nights Are More Beautiful Than Your Days',
#   'Become the Warm Jets',
#   'Fear',
#   'Fear'],
#  (4, 'Dion'): ['Abraham, Martin And John'],
#  (4, 'Dominic Fike'): ['Superstar Sh*t'],
#  (4, 'FKJ, Bas'): ['Risk'],
#  (4, 'Father'): ['ICEMAN'],
#  (4, 'Flatsound'): ["You Wrote 'Don't Forget' On Your Arm",
#   'If We Could Just Pretend'],
#  (4, 'Fog Lake'): ['Lost Love Letters'],
#  (4, 'Frank Ocean'): ['Ivy'],
#  (4, 'Glass Animals'): ['Domestic Bliss'],
#  (4, 'Godford'): ['Dawntown'],
#  (4, 'Goth Babe'): ['Car Camping'],
#  (4, 'Great Dane, Katya Grasso'): ['The Lonely Ones - Great Dane Remix'],
#  (4, 'Healy'): ['Nikes On'],
#  (4, 'Hooligin'): ['Jets & Cigarettes'],
#  (4, 'JR JR'): ['Good Old Days'],
#  (4, 'Jarryd James, Raury'): ['Do You Remember'],
#  (4, 'Jay Electronica'): ['Fruits Of The Spirit'],
#  (4, 'Jessie Murph'): ['Pray'],
#  (4, 'Jetson, [bsd.u]'): ['Bluntscraps'],
#  (4,
#   'Johan Lenox, Lil Keed, Kota the Friend'): ['throwback thursday (chamber version) feat. Lil Keed & KOTA The Friend'],
#  (4, 'Joshua Burnside'): ['Whiskey Whiskey'],
#  (4, 'Jullian, Sophie Wood'): ['Buttercup'],
#  (4, 'Kamal.'): ['about the party'],
#  (4, 'Kanye West'): ['Come to Life', 'Moon'],
#  (4, 'Kendrick Lamar'): ['Crown'],
#  (4, 'Kidswaste'): ['Need You'],
#  (4, 'Labrinth'): ['When I R.I.P.'],
#  (4, 'Leagues'): ['Slow And Steady'],
#  (4, 'Lil Peep'): ['Gym Class'],
#  (4, 'MOSSS'): ['Sleeping With You', 'IDK'],
#  (4, 'Mac DeMarco'): ['Still Beating'],
#  (4, 'Mac Miller'): ['Circles', 'Dunno'],
#  (4, 'MarMar Oso'): ['Ruthless (Nice Guys Always Finish Last)'],
#  (4, 'Men I Trust'): ['Pines'],
#  (4, 'More Fatter'): ['Rae'],
#  (4, 'Neil Young'): ['Harvest Moon'],
#  (4, 'Nick Leng, Chester Watson'): ['Plastic Moon'],
#  (4, 'Niko Rose'): ['So Light'],
#  (4, 'ODESZA, Regina Spektor'): ['Just A Memory (feat. Regina Spektor)',
#   'Just A Memory (feat. Regina Spektor)'],
#  (4, 'ODIE'): ['Miss Summer'],
#  (4, 'Oscar Welsh'): ['Drift'],
#  (4, 'Osquello'): ['Simulated Void'],
#  (4,
#   'Phoebe Bridgers'): ['Friday I’m In Love - Recorded at Spotify Studios NYC'],
#  (4, 'Pinstripe Sunny'): ['Giant Monsters All Out Attack!'],
#  (4, 'Post Malone'): ['Feeling Whitney'],
#  (4, 'Radiohead'): ['Talk Show Host'],
#  (4, 'Rainbow Kitten Surprise'): ["That's My Shit", 'Lady Lie'],
#  (4, 'Ralph Castelli'): ['Four Below'],
#  (4, 'Rex Orange County'): ['Belly (The Grass Stains)'],
#  (4, 'Ritt Momney'): ['Phoebe'],
#  (4, 'Roy Blair'): ['Hazel'],
#  (4, 'SALES'): ['Pope Is a Rockstar'],
#  (4, 'SEBASTIAN PAUL'): ['ON SOME HIGH'],
#  (4, 'Scruffpuppie'): ['Ego'],
#  (4, 'Setec'): ['Water or Concrete'],
#  (4, 'Shrimp'): ['sewed shut'],
#  (4, 'Simon & Garfunkel'): ['April Come She Will'],
#  (4, 'Sir Sly'): ['All Your Love'],
#  (4, 'Smeyeul., Galvanic'): ['Boyfriend'],
#  (4, 'Soft Glas, Mulherin'): ['The Bay (feat. Mulherin)'],
#  (4, 'Still Woozy'): ['These Days'],
#  (4, 'Strawberry Guy'): ['F Song'],
#  (4, 'Ted Lucas'): ['Plain & Sane & Simple Melody'],
#  (4, 'The Dø'): ['Dust It Off'],
#  (4, 'Throttle'): ['Cities'],
#  (4, 'Tinlicker, Helsloot'): ['Because You Move Me'],
#  (4, 'Tiny Little Houses'): ["I Hate That You're Happy"],
#  (4, 'Trippie Redd'): ['Taking A Walk'],
#  (4, 'Trisha Mohring'): ['It Runs Deep'],
#  (4, 'Vansire'): ['Moon Hits'],
#  (4, 'Vansire, Paul Cherry, Mellow Fellow, Ruru'): ['Lonely Zone'],
#  (4, 'Waxahatchee'): ['Fire'],
#  (4, 'XXXTENTACION'): ['Revenge',
#   'the remedy for a broken heart (why am I so in love)',
#   'changes'],
#  (4, 'Yellow House'): ['Better Views', 'Love in the Time of Socialism'],
#  (4,
#   'Young Thug, Gunna, Jeff Bhasker, Nate Ruess'): ['Love You More (with Nate Ruess, Gunna & Jeff Bhasker)'],
#  (4, 'Yung Lean'): ['Red Bottom Sky', 'Agony'],
#  (4, 'Zach Bryan'): ['Heading South', 'God Speed'],
#  (4, 'Zach Winters'): ['If the Sun Is Shining'],
#  (4, 'aloneintokyo'): ['Fault Lines'],
#  (4, 'awfultune, Sandosius'): ['Things That I Miss'],
#  (4, 'beabadoobee'): ['How Was Your Day?'],
#  (4, 'beabadoobee, Oscar Lang'): ['The Moon Song'],
#  (4, 'bülow'): ['Lost'],
#  (4, 'carobae'): ['When All My Friends Move Away'],
#  (4, 'j ember'): ['something more'],
#  (4, 'lentra'): ['Violent; Still'],
#  (4, 'lil aaron'): ['Dark Matter'],
#  (4, 'rei brown'): ['Picture Frames'],
#  (4, 'vanta blvck'): ['Waiting'],
#  (5, '2Pac, Outlawz'): ["Hit 'Em Up - Single Version"],
#  (5, '347aidan'): ['MEMORIES!'],
#  (5, '6LACK'): ['Ex Calling'],
#  (5, '99 Neighbors'): ['QWOP'],
#  (5, 'Action Bronson, Statik Selektah'): ['Not Enough Words'],
#  (5, 'Blvck Svm'): ['bleach'],
#  (5, 'Bslime, Young Thug'): ['Real Talk'],
#  (5, 'CHASE PAVES, Lucca'): ['Bed Time'],
#  (5, 'Connor Price'): ['Chatter', 'SPLAT'],
#  (5, 'Cordae'): ['Thornton Street'],
#  (5, 'Current Blue'): ['Six Speed'],
#  (5, 'Da Deputy, Jalen Santoy'): ["Did or Didn't"],
#  (5, 'DaBaby'): ['PRACTICE'],
#  (5,
#   'Death Cab for Cutie, Louis The Child'): ['I Dreamt We Spoke Again - Louis the Child Remix'],
#  (5, 'Domani'): ['Homesick'],
#  (5, 'Drake, 2 Chainz, Young Thug'): ['Sacrifices'],
#  (5, 'EKKSTACY'): ['stupid kids'],
#  (5, 'Flume, Reo Cragun'): ['Quits'],
#  (5, 'Freddie Gibbs'): ['Big Boss Rabbit'],
#  (5, 'Freddie Gibbs, ScHoolboy Q'): ['Gang Signs (feat. ScHoolboy Q)'],
#  (5, 'Future'): ['All Right'],
#  (5, 'Future, Lil Uzi Vert'): ['Drankin N Smokin'],
#  (5, 'Goth Babe'): ['Running Around'],
#  (5, 'Gunna, Nechie'): ['ADDYS (feat. Nechie)'],
#  (5, 'Gunna, Young Thug'): ['Cop Me a Foreign (feat. Young Thug)'],
#  (5,
#   'ILLENIUM, Joni Fatora'): ['Fortress (Just A Gent Remix) [feat. Joni Fatora]'],
#  (5, 'JAY-Z'): ['JAY Z Blue', 'Marcy Me'],
#  (5, 'JAY-Z, Kanye West'): ['Murder To Excellence'],
#  (5, 'JAY-Z, Mecca'): ["Feelin' It"],
#  (5, 'Juice WRLD'): ['All Girls Are The Same',
#   'Black & White',
#   'Blood On My Jeans'],
#  (5, 'Kanye West'): ['Keep My Spirit Alive'],
#  (5, 'Key Glock'): ['Dough'],
#  (5, 'King Geedorah, Mr Fantastik'): ['Anti-Matter'],
#  (5, 'Kota the Friend'): ['Scapegoat', 'Pomegranate'],
#  (5, 'Lil Baby, Gunna'): ['I Am (Lil Baby & Gunna)'],
#  (5, 'Lil Eazzyy'): ['Onna Come Up'],
#  (5,
#   'Lil Tecca, Polo G, Lil Durk'): ['When You Down (with Polo G feat. Lil Durk)'],
#  (5, 'Lil Tjay'): ['Losses - Bonus'],
#  (5, 'Loutribe Jigg'): ['Facts'],
#  (5, 'Luke Wild'): ['Easier To Lie'],
#  (5, 'MF DOOM, DJ Cucumber Slice'): ['Rhymes Like Dimes'],
#  (5, 'MUTO, Emerson Leif'): ['Say Nothing'],
#  (5, 'Mac Miller'): ['Thoughts from a Balcony'],
#  (5, 'Mac Miller, Earl Sweatshirt'): ['Polo Jeans (feat. Earl Sweatshirt)'],
#  (5, 'Machinedrum, Freddie Gibbs'): ['Kane Train'],
#  (5, 'Madvillain, Madlib, MF DOOM'): ['All Caps'],
#  (5, 'Marlon Craft'): ['Somethin Wrong In Heaven'],
#  (5,
#   'Martin Garrix, Dua Lipa, Medasin'): ['Scared To Be Lonely - Medasin Remix'],
#  (5, 'Moi Je, Petit Biscuit'): ['Fais rien (Petit Biscuit Remix)'],
#  (5, 'Montana99'): ["I Can't"],
#  (5, 'NAV, Lil Baby'): ["Don't Need Friends (feat. Lil Baby)"],
#  (5, 'Nas'): ['Blue Benz'],
#  (5, 'Nas, A$AP Rocky, DJ Premier'): ['Wave Gods'],
#  (5, 'Nas, Charlie Wilson'): ['Car #85 (feat. Charlie Wilson)'],
#  (5, 'Noname'): ['Song 33'],
#  (5, 'Party Favor, JAHMED'): ['ACTUP (with JAHMED)'],
#  (5, 'Payday'): ['Beam'],
#  (5, 'Payday, Jackboy'): ['Beam, Pt. 2 (feat. Jackboy)'],
#  (5, 'Playboi Carti, Lil Uzi Vert'): ['wokeuplikethis*'],
#  (5, 'Polo G'): ['Through Da Storm', 'RAPSTAR'],
#  (5, 'Rakim'): ['Strong Island', 'When I B On Tha Mic', 'Flow Forever'],
#  (5, 'SEBASTIAN PAUL'): ['TROJAN HORSE'],
#  (5, 'Shakewell, Mikey The Magician'): ['Leglock'],
#  (5, 'Smino, JID, Kenny Beats'): ['Baguetti (with JID & Kenny Beats)'],
#  (5, 'Subsonic'): ['Love VIP'],
#  (5, 'T2, ARPA'): ['Heartbroken 2022'],
#  (5, 'The Notorious B.I.G.'): ['Hypnotize - 2007 Remaster'],
#  (5, 'The Pharcyde'): ['Soul Flower - Remix',
#   "I'm That Type Of Nigga",
#   'Oh Shit'],
#  (5, 'Trent the HOOLiGAN'): ['My Friends'],
#  (5, 'Viktor Vaughn, MF DOOM'): ['Lickupon'],
#  (5, 'Young Dolph'): ['100 Shots'],
#  (5, 'Young Money, Drake'): ['Trophies'],
#  (5, 'Young Thug'): ['RiRi', 'Killed Before', 'Icey'],
#  (5, 'Young Thug, A$AP Ferg, Freddie Gibbs'): ['Old English'],
#  (5, 'YoungBoy Never Broke Again, Quavo'): ['Don’t Rate Me (feat. Quavo)'],
#  (5, 'Yunggoth✰'): ['Love Hurts'],
#  (5, 'Zaytoven, Gucci Mane, 21 Savage'): ['East Atlanta Day'],
#  (5, 'femdot.'): ['94 Camry Music'],
#  (5, 'ford., Verzache'): ['In My Eyes', 'In My Eyes (feat. Verzache)'],
#  (5, 'lentra'): ['Apathy of No One'],
#  (6, '12k Gotti'): ['TLC'],
#  (6, '2Pac, Outlawz'): ["They Don't Give A F**** About Us"],
#  (6, '99 Neighbors'): ['Facts'],
#  (6, '9lokknine'): ['Fun Facts'],
#  (6, 'AG Club'): ['Hngover'],
#  (6, 'Arden Jones'): ['starstruck', 'la di da - acoustic'],
#  (6,
#   'BROCKHAMPTON, A$AP Rocky, A$AP Ferg'): ['BANKROLL (feat. A$AP Rocky & A$AP Ferg)'],
#  (6, 'Bassnectar, Zumbi'): ['Teleport Massive (feat. Zumbi)'],
#  (6,
#   'DJ Khaled, French Montana, Meek Mill, Beanie Sigel, Jadakiss'): ['I Lied (feat. French Montana, Meek Mill, Beanie Sigel & Jadakiss)'],
#  (6, 'Dave, Burna Boy'): ['Location (feat. Burna Boy)'],
#  (6, 'Eric Reprid'): ['Get More'],
#  (6, 'Fasion'): ['No Cry'],
#  (6, 'Felly, Gyyps'): ['Desert Eagle'],
#  (6, 'Future, Lil Uzi Vert'): ['That’s It'],
#  (6, 'Future, Young Thug'): ['Group Home', 'Drip on Me'],
#  (6, 'GRIP'): ['Chicken N Dumplins'],
#  (6, 'Gunna, Lil Baby'): ['Sold Out Dates (feat. Lil Baby)'],
#  (6, 'Heno., Ciscero, Wax Roof'): ['Coffee'],
#  (6,
#   'Hermitude, Soaky Siren, Vory'): ['Northern Lights (feat. Soaky Siren & Vory)'],
#  (6, 'J. Cole'): ['Sideline Story'],
#  (6,
#   'J. Cole, Lil Baby'): ['p r i d e . i s . t h e . d e v i l (with Lil Baby)'],
#  (6, 'J. Cole, Missy Elliott'): ["Nobody's Perfect"],
#  (6, 'JACKBOYS, Sheck Wes'): ['GANG GANG'],
#  (6, 'JAY-Z'): ['Dead Presidents II'],
#  (6, 'Joseph Black'): ['(i hope you) miss me'],
#  (6,
#   'Kanye West, JAY-Z, J. Ivy'): ['Never Let Me Down - Album Version (Edited)'],
#  (6, 'Kendrick Lamar'): ['Rich Spirit', 'Rich Spirit'],
#  (6, 'Kodak Black'): ['Already'],
#  (6, 'LUCKI'): ['Count on Me II'],
#  (6, 'Leach'): ['Little Taste of Heaven'],
#  (6, 'Lil Baby, Drake'): ['Yes Indeed'],
#  (6, 'Lil Durk, 6LACK, Young Thug'): ['Stay Down (with 6LACK & Young Thug)'],
#  (6, 'Lil Keed, Lil Duke, Gunna'): ['Anybody (feat. Lil Duke & Gunna)'],
#  (6, 'Lil Keed, O.T. Genasis'): ['Show Me What You Got (feat. O.T. Genasis)'],
#  (6,
#   'Ludacris, Lil Wayne'): ['S.O.T.L. (Silence of the Lambs) [feat. Lil Wayne]'],
#  (6, 'MAVI'): ['Self Love'],
#  (6, 'Madvillain, Madlib, MF DOOM'): ['Accordion'],
#  (6, 'Masego'): ['Navajo'],
#  (6, 'Maxd, LoneMoon'): ['Stuart'],
#  (6,
#   'Meek Mill, Young Thug, 21 Savage'): ['Offended (feat. Young Thug & 21 Savage)'],
#  (6, 'Morray'): ['Quicksand'],
#  (6, 'Nas, Diddy, 070 Shake'): ['Not For Radio'],
#  (6, 'Nas, Ms. Lauryn Hill'): ['Nobody (feat. Ms. Lauryn Hill)'],
#  (6,
#   'Nyck Caution, Erick the Architect, Kota the Friend'): ['Product Of My Environment (feat. Kota the Friend & Erick the Architect)'],
#  (6, 'Polo G'): ['I Know'],
#  (6,
#   'Pop Smoke, Lil Baby, DaBaby'): ['For The Night (feat. Lil Baby & DaBaby)'],
#  (6, 'Rakim'): ['I Know'],
#  (6, 'Rakim, Connie McKendrick'): ["We'll Never Stop"],
#  (6, 'Royal & the Serpent'): ['overwhelmed'],
#  (6, 'Ryan Trey'): ['Mutual Butterflies'],
#  (6, 'SALES'): ['Chinese New Year'],
#  (6,
#   'Spillage Village, EARTHGANG, JID, Jurdan Bryant, Mereba, Hollywood JB'): ['End Of Daze (with EARTHGANG & JID feat. Jurdan Bryant, Mereba & Hollywood JB)'],
#  (6, 'Still Woozy'): ['Window'],
#  (6, 'Still Woozy, ODIE'): ['Lucy'],
#  (6, 'The Mouse Outfit, Sparkz'): ["Got Me Thinkin' (feat. Sparkz)"],
#  (6, 'The Pharcyde'): ['Drop', "Passin' Me By"],
#  (6,
#   'Tobe Nwigwe, Pharrell Williams, EARTHGANG, Fat Nwigwe'): ['LORD FORGIVE ME'],
#  (6, 'Tom The Mail Man'): ['Forever'],
#  (6, 'TrillNagi, Chri$ Trill'): ['Pull Up'],
#  (6, 'UnoTheActivist, Travis Barker'): ['Taste The Rainbow'],
#  (6, 'Viktor Vaughn, MF DOOM'): ['Lactose and Lecithin'],
#  (6, 'Wiz Khalifa'): ['Bootsy Bellows'],
#  (6, 'XXXTENTACION'): ['Riot', 'Jocelyn Flores'],
#  (6,
#   'Young Stoner Life, Young Thug, Gunna, Travis Scott'): ['Diamonds Dancing (feat. Travis Scott)'],
#  (6, 'Young Thug'): ['Just Might Be'],
#  (6, 'Young Thug, Duke'): ['Webbie (feat. Duke)'],
#  (6, 'YoungBoy Never Broke Again, Lil Wayne'): ['My Window (feat. Lil Wayne)'],
#  (6, 'Yxngxr1'): ['emma, u up?'],
#  (6, 'maxime.'): ['wys'],
#  (6, 'slowthai, A$AP Rocky'): ['MAZZA (feat. A$AP Rocky)'],
#  (7, '100 gecs'): ['mememe'],
#  (7, '333, Vague003'): ['Wild Place'],
#  (7, '6host'): ['Borderline'],
#  (7, 'Aaron Trinh, Midnight Sky, ENROSA'): ['Sapphire'],
#  (7, 'Arden Jones'): ['mr. sunshine'],
#  (7, 'Ariana Grande, Zedd'): ['Break Free'],
#  (7, 'BLOW'): ['Dancing Waters'],
#  (7, 'Beach Fossils'): ['This Year'],
#  (7, 'Blue Öyster Cult'): ["Burnin' for You", "(Don't Fear) The Reaper"],
#  (7, 'BØRNS'): ['American Money'],
#  (7,
#   'Calcutta , Takagi & Ketra'): ['Oroscopo (feat. Takagi & Ketra) - Ghost track'],
#  (7, 'DJ Fixx'): ['Die Young - Original Mix'],
#  (7, 'Dagny, BØRNS'): ["Fool's Gold"],
#  (7, 'Deb Never, Jim-E Stack'): ['Sweet & Spice', 'Sweet & Spice'],
#  (7, 'Destroy Lonely'): ['NOSTYLIST'],
#  (7, 'Drake'): ['Headlines'],
#  (7, 'Erick the Architect'): ["I Can't Lose"],
#  (7, 'Fitz and The Tantrums'): ['Out of My League'],
#  (7, 'Freddie Gibbs, Madlib, Alex Goose'): ["Thuggin' (Alex Goose Remix)"],
#  (7, 'GOON DES GARCONS*, Cuco'): ['A24'],
#  (7, 'Grimes'): ['Genesis'],
#  (7, 'Gus Dapperton'): ['First Aid', 'Prune, You Talk Funny', 'First Aid'],
#  (7, 'HWLS, Trapo'): ['Shade of'],
#  (7, 'Halsey'): ['Nightmare'],
#  (7, 'INZO, Novet'): ['Visionaries (feat. Novet)'],
#  (7, 'Interpol'): ['Rest My Chemistry'],
#  (7, 'Jaxx'): ['Like This!'],
#  (7, 'John Summit, SIDEPIECE'): ['Deep End - SIDEPIECE Remix'],
#  (7, 'Josh Augustin, Eva Alexis'): ['Midtown'],
#  (7, 'Juice WRLD'): ['Rockstar In His Prime'],
#  (7, 'KIDS SEE GHOSTS'): ['Cudi Montage'],
#  (7, 'Kanye West'): ['Big Brother'],
#  (7, 'Kavinsky'): ['Nightcall'],
#  (7, 'Kevin Gates'): ['Great Example'],
#  (7, 'King Geedorah, Hassan Chop'): ['I Wonder'],
#  (7, 'Kodak Black'): ['Can I'],
#  (7, 'Kyle Lux'): ["Rollin' Stone"],
#  (7, 'LEVR, Nimez, Drama B'): ['Waiting'],
#  (7, 'Lil Peep'): ['IDGAF', 'nineteen'],
#  (7, 'Lil Tracy'): ['Ghost'],
#  (7, 'Lil Uzi Vert'): ['Baby Pluto'],
#  (7, 'Lonely God'): ['Sunday'],
#  (7, 'Lord Lu C N, Denzel Curry, Anna Wise'): ['A.S.S.'],
#  (7, 'Louis The Child, BabyJake'): ['Somewhere Else (with BabyJake)'],
#  (7, 'Lowly, Juche'): ['Synergy'],
#  (7, 'Mac DeMarco'): ['On the Level'],
#  (7, 'Mac Miller'): ['Ayye', 'The Spins'],
#  (7, 'Marco Luka'): ['do me wrong'],
#  (7, 'Maribou State, Holly Walker'): ['Midas'],
#  (7, 'Metric, Brie Larson'): ['Black Sheep - Brie Larson Vocal Version'],
#  (7,
#   'Mike WiLL Made-It, Lil Wayne, Kendrick Lamar, Future'): ['Buy The World'],
#  (7, 'Mobb Deep'): ['Shook Ones, Pt. II'],
#  (7, 'Moksi, Elayna Boynton'): ['Slow Burn'],
#  (7, 'Nafets, Zach Ezzy'): ['Hooped'],
#  (7, 'Nimez'): ['Emerge'],
#  (7, 'Nonplussed'): ['PARTY'],
#  (7, 'ODESZA'): ['La Ciudad'],
#  (7, 'Oski, The Arcturians'): ['Go My Way'],
#  (7, 'Paris Shadows'): ['Bones'],
#  (7, 'Peach Face, Modern Nomad'): ['Ghost'],
#  (7, 'Peach Pit'): ['Alrighty Aphrodite'],
#  (7, 'Porter Robinson, Amy Millan, ODESZA'): ['Divinity - ODESZA Remix'],
#  (7, 'Portugal. The Man'): ['Easy Tiger'],
#  (7,
#   'Portugal. The Man, Mary Elizabeth Winstead, Zoe Manville'): ['Noise Pollution (feat. Mary Elizabeth Winstead & Zoe Manville) - Version A, Vocal up Mix 1.3'],
#  (7, 'Quarters of Change'): ['Dead'],
#  (7, 'ROLE MODEL, BENEE'): ['notice me (feat. BENEE)'],
#  (7, 'Racoma'): ['Furthermore'],
#  (7, 'Rebounder'): ['Lovers'],
#  (7, 'Rezz'): ['Levitate'],
#  (7, 'SLANDER, YOOKiE, Zach Sorgen'): ['One Life (feat. Zach Sorgen)'],
#  (7, 'Sad Night Dynamite'): ['Black & White'],
#  (7, 'Smiley, Drake'): ['Over The Top (feat. Drake)'],
#  (7, 'Sneaker Pimps'): ['Post Modern Sleaze'],
#  (7, 'Steve Lacy'): ['Basement Jack'],
#  (7, 'Sufjan Stevens'): ['Video Game'],
#  (7, 'Surf Curse'): ['Disco'],
#  (7, 'TV Girl'): ['Lovers Rock'],
#  (7,
#   'Tep No, Lizz Kellerman'): ["It's Alright (NGHTMRE Remix) [feat. Lizz Kellerman]"],
#  (7, 'The Growlers'): ['Dream World', 'Try Hard Fool'],
#  (7, 'The Last Skeptik, LCYTN'): ['I Like That'],
#  (7, 'Tom The Mail Man'): ['Traveling Alone'],
#  (7, 'TyFontaine'): ['End Of Time'],
#  (7,
#   'WILLOW, Travis Barker'): ['t r a n s p a r e n t s o u l feat. Travis Barker'],
#  (7, 'Wallows, Clairo'): ['Are You Bored Yet? (feat. Clairo)'],
#  (7, 'Widespread Panic'): ['All Time Low'],
#  (7, 'Wiley from Atlanta'): ['Pink Skies (Demo)'],
#  (7, 'YNW BSlime, YNW Melly, Trippie Redd, YNW Bortlen'): ['The Mob'],
#  (7, 'YNW Melly, Juice WRLD'): ['Suicidal (Remix) [feat. Juice WRLD]'],
#  (7, 'Yoke Lore'): ['Goodpain'],
#  (7, 'YoungBoy Never Broke Again'): ['No Love'],
#  (7, 'Yung Pinch'): ['Perfect'],
#  (7, 'cleopatrick'): ['hometown'],
#  (7, 'ford., sophie meiers'): ['Warmth'],
#  (7, 'gravehours, guardin, abbot'): ['FRIENDS'],
#  (7, 'iann dior'): ['let you'],
#  (7, 'my!lane'): ['This Feeling'],
#  (7, 'shy kids'): ['Backward in Love'],
#  (7, 'veggi, KhakiKid, Ben Beal'): ['RAINCLOUDS'],
#  (8, 'Duffle Bag Buru'): ['Bust Back'],
#  (8, 'Flume'): ['Go'],
#  (8, 'GHOST DATA, Jovani Occomy'): ['Celestial Bodies'],
#  (8, 'Johnny Goth'): ["Feels Like We're Dying"],
#  (8, 'Nas'): ['Dance'],
#  (8, 'The Kid LAROI'): ['SELFISH'],
#  (9, "2Pac, Rappin' 4-Tay"): ["Only God Can Judge Me (ft. Rappin' 4-Tay)"],
#  (9, 'Aaron Taos'): ['Control'],
#  (9, 'Arden Jones'): ['run wild', 'horror story'],
#  (9, 'Aries'): ['RIDING', 'BAD NEWS', "FOOL'S GOLD"],
#  (9, 'Bakar'): ['Been a Minute'],
#  (9, 'Brainstory'): ['Fruitless Trees'],
#  (9, 'Brasstracks, Lido, FATHERDUDE'): ['Telling the Truth'],
#  (9, 'CJ'): ['Whoopty'],
#  (9, 'Cannibal Kids, Yucky Poor'): ['Go Outside'],
#  (9, 'Chris Brown, Young Thug'): ['Go Crazy'],
#  (9, 'Clean Bandit, iann dior'): ['Higher (feat. iann dior)'],
#  (9, 'Creedence Clearwater Revival'): ['Good Golly Miss Molly'],
#  (9, 'Current Blue'): ['Los Santos'],
#  (9, 'DDG, Blueface'): ['Moonwalking in Calabasas (feat. Blueface) - Remix'],
#  (9, 'Dominic Fike'): ['Babydoll'],
#  (9, 'Fleece'): ['Upside Down'],
#  (9, 'Flume, Chet Faker'): ['This Song Is Not About A Girl'],
#  (9, 'Flume, Reo Cragun'): ['Levitate'],
#  (9, 'Fred again.., The Blessed Madonna'): ['Marea (we’ve lost dancing)'],
#  (9, 'G-Eazy, Yo Gotti, YBN Nahmir'): ['1942 (feat. Yo Gotti & YBN Nahmir)'],
#  (9, 'GEE LEE'): ['Coke & Rum'],
#  (9, 'Gatlin'): ['never been in love'],
#  (9, 'Grapetooth'): ['Red Wine'],
#  (9, 'Gunna'): ['Japan'],
#  (9, 'Gus Dapperton'): ['My Favorite Fish'],
#  (9, 'Internet Money, Gunna, Don Toliver, NAV'): ['Lemonade',
#   'Lemonade (feat. Gunna, Don Toliver & NAV)'],
#  (9, 'Isaac Zale, Sylvan LaCue'): ['Eyelids'],
#  (9, 'Jack Harlow'): ['Tyler Herro'],
#  (9, 'Joji'): ['Tick Tock'],
#  (9, 'Juice WRLD'): ['Hear Me Calling'],
#  (9, 'Julian Skiboat'): ['whiskey'],
#  (9, 'Just Friends'): ['Fever'],
#  (9, 'KEY!, Bobby Raps'): ["Boys Don't Cry (feat. Bobby Raps)"],
#  (9, 'Kendrick Lamar'): ['The Heart Part 5'],
#  (9, 'Kendrick Lamar, Kodak Black'): ['Silent Hill'],
#  (9, 'Kinneret'): ['No Wind Resistance SPED UP!'],
#  (9, 'Lewis Del Mar'): ['Rosalie (CH. II)'],
#  (9, 'Lil Nas X'): ['HOLIDAY'],
#  (9, 'MICHELLE'): ['THE BOTTOM'],
#  (9, 'Mac Miller'): ['It Just Doesn’t Matter'],
#  (9, 'Macross 82-99'): ['『82.99 F.M』'],
#  (9, 'Mako Road'): ['The Green Superintendent'],
#  (9, 'Masego, Don Toliver'): ['Mystery Lady (feat. Don Toliver)'],
#  (9, 'Maxo Kream'): ['Grannies'],
#  (9, 'Men I Trust'): ['Tailwhip'],
#  (9, 'Men I Trust, Helena'): ['Break for Lovers (feat. Helena)'],
#  (9, 'Moe Shop, maisou'): ['Lovesick'],
#  (9, 'Moneybagg Yo'): ['Me Vs Me'],
#  (9, 'Mosie'): ['Oh! Frenchy'],
#  (9, 'MyKey'): ["Please Don't Go"],
#  (9, 'NEIL FRANCES, The Undercover Dream Lovers'): ['Tell Me'],
#  (9, 'NLE Choppa, Big Sean'): ['Moonlight (feat. Big Sean)'],
#  (9, 'Nas'): ['N.Y. State of Mind'],
#  (9, 'Nick Bonin'): ['Fell Too Far'],
#  (9, 'Nick Leng'): ['Walking Home to You'],
#  (9, 'Nocturnal'): ['Car Ride Home'],
#  (9, 'Oscar Scheller'): ['Peach'],
#  (9, 'Peach Pit'): ['Techno Show'],
#  (9, 'Portugal. The Man'): ['So Young', 'Feel It Still'],
#  (9, 'Quentin Miller'): ['Bank!!!'],
#  (9, 'RIZ LA VIE'): ['Saturn'],
#  (9, 'Rakim'): ['Uplift'],
#  (9, 'Rakim, Nneka Morton'): ["I'll Be There"],
#  (9, 'Rebounder'): ['Japanese Posters'],
#  (9, 'Shelly'): ['Steeeam'],
#  (9, 'Short Moscato, leaseybeans'): ['Everything We Dream'],
#  (9, 'SiR'): ['John Redcorn'],
#  (9, 'Steve Lacy'): ['N Side'],
#  (9, 'Still Woozy'): ["That's Life", 'Woof'],
#  (9, 'Strawberry Milk Cult'): ['MF Gloom'],
#  (9, 'Student 1'): ['Nippy', 'Nippy'],
#  (9, 'Sybyr'): ['Then We Get Nast(y)'],
#  (9, 'Tchami, Gunna'): ['Praise (feat. Gunna)'],
#  (9, 'The Beatles'): ["Octopus's Garden - Remastered 2009"],
#  (9, 'The Heavy'): ['Short Change Hero'],
#  (9,
#   'The Kid LAROI, YoungBoy Never Broke Again, Internet Money'): ['TRAGIC (feat. Youngboy Never Broke Again & Internet Money)'],
#  (9, 'The Marías'): ['Hush'],
#  (9, 'The Pharcyde'): ["Runnin'"],
#  (9, 'The Rolling Stones'): ['Miss You - Remastered'],
#  (9, 'TiDUS'): ['Each Time'],
#  (9, 'Tony Velour'): ['Unfazed'],
#  (9, 'TyFontaine'): ['Sticky'],
#  (9,
#   'Tyla Yaweh, Trippie Redd, PnB Rock'): ['Do No Wrong (feat. Trippie Redd & PnB Rock)'],
#  (9, 'Uncle Bendr'): ['Boy'],
#  (9, 'Viktor Vaughn, MF DOOM'): ['Mr. Clean'],
#  (9, 'Wallows'): ['Scrawny'],
#  (9, 'YTK'): ['Gilligan'],
#  (9, 'Young Stoner Life, Young Thug, Gunna'): ['Ski'],
#  (9, 'Young Thug'): ['Wyclef Jean'],
#  (9, 'Young Thug, Juice WRLD'): ['Mannequin Challenge (feat. Juice WRLD)'],
#  (9, 'Young Thug, Wyclef Jean'): ['Kanye West (feat. Wyclef Jean)'],
#  (9, 'bbno$, Diamond Pistols, BENEE'): ['help herself (with BENEE)'],
#  (9, 'half•alive'): ['still feel.'],
#  (9, 'j ember'): ['Your Drugs'],
#  (9, 'lilbootycall, Juicy J'): ['18K (feat. Juicy J)'],
#  (9, 'not dvr'): ['lonely'],
#  (9, 'pizzagirl'): ['gymnasium'],
#  (9,
#   'slenderbodies, Crooked Colours'): ['superpowerful (with Crooked Colours)'],
#  (9, 'tobi lou'): ["I Was Sad Last Night I'm OK Now"],
#  (9, 'Łaszewo'): ['Up in Flames'],
#  (10, '$uicideboy$'): ['Kill Yourself (Part III)'],
#  (10, '24kGoldn'): ['GAMES ON YOUR PHONE'],
#  (10, 'ASL'): ['Cinnamon Girl'],
#  (10, 'Ace Savage'): ['Scheming'],
#  (10, 'Animals in the Attic'): ['Take Care'],
#  (10, 'Arden Jones, Allen Haley'): ['serotonin highs (feat. Allen Haley)'],
#  (10, 'Aries'): ['KIDS ON MOLLY', 'PONY'],
#  (10, 'BONNIE X CLYDE'): ['Leave It All Behind'],
#  (10, 'BROODS, NASAYA'): ['Peach - NASAYA Remix'],
#  (10, 'BRUER'): ['Fall Hard'],
#  (10, 'Beach House'): ['Space Song'],
#  (10, 'Belly, The Weeknd, Nas'): ['Die For It (ft. Nas)'],
#  (10, 'Big Sean'): ['Why Would I Stop?'],
#  (10, 'Big Wild, Yuna, Cabu'): ['Empty Room - Cabu Remix'],
#  (10, 'Blu DeTiger'): ['Cotton Candy Lemonade'],
#  (10, 'Charmes'): ['Crack It'],
#  (10, 'Choo Jackson, Mac Miller'): ['HD (feat. Mac Miller)'],
#  (10, 'Chris Lake'): ['400'],
#  (10, 'Danny L Harle, DJ Danny, Flume'): ['On A Mountain - Flume Remix'],
#  (10, 'Devon Again'): ['HEAD'],
#  (10, 'Djo'): ['Mortal Projections'],
#  (10, 'Dominic Fike'): ['Westcoast Collective'],
#  (10, 'Ekali, K.Flay'): ['Forgot How To Dream (feat. K.Flay)'],
#  (10, 'Elvis Depressedly'): ['Who Can Be Loved In This World?'],
#  (10, 'Emma Peters, Crisologo'): ['Possédé'],
#  (10, 'Eprom'): ['9 to Ya Dome'],
#  (10, 'Eryn Martin'): ['Ball'],
#  (10, 'Fabian Mazur'): ['Takeover'],
#  (10, 'Flume, LAUREL'): ["I Can't Tell (feat. LAUREL)"],
#  (10, 'Flume, QUIET BISON, KUČKA'): ['ESCAPE (feat. KUČKA)'],
#  (10, 'Flux Pavilion, Asha'): ['I Believe'],
#  (10, 'Foster The People'): ['Static Space Lover'],
#  (10, 'Future'): ['Solo'],
#  (10, 'Giant Rooks'): ['What I Know Is All Quicksand'],
#  (10, 'Goodbye Honolulu'): ['Typical'],
#  (10, 'Grady'): ['CAN YOU HEAR THE MOON'],
#  (10, 'Hana Vu'): ['Keeper'],
#  (10, 'Heuse, Alltair'): ['Truth'],
#  (10, 'Hikes'): ["been thinkin'"],
#  (10, 'Hippie Sabotage'): ['Overdrive'],
#  (10, 'ILLENIUM, Dia Frampton'): ['Needed You'],
#  (10,
#   'Isaiah Rashad, Jay Rock, Jay Worthy'): ['True Story (feat. Jay Rock & Jay Worthy)'],
#  (10,
#   'J. Cole, 21 Savage, Morray'): ['m y . l i f e (with 21 Savage & Morray)'],
#  (10, 'J. Cole, Bas'): ['1 0 0 . m i l ‘ (with Bas)'],
#  (10, 'Jay Electronica'): ['The Neverending Story'],
#  (10, 'Joji'): ['YUKON (INTERLUDE)'],
#  (10, 'Juice WRLD'): ['Burn', 'Fast', 'Lucid Dreams'],
#  (10, 'Just A Gent, Kasbo'): ['Sovereign'],
#  (10, 'Kaivon'): ['I Love You.'],
#  (10, 'Kaivon, Stella Smyth'): ['Mind Is All Yours'],
#  (10, 'Kanye West'): ['Heaven and Hell', 'Facts (Charlie Heat Version)'],
#  (10, 'Kid Cudi'): ['She Knows This'],
#  (10, 'Led Zeppelin'): ['Black Dog - Remaster'],
#  (10, 'Lil Baby'): ['Freestyle', 'Emotionally Scarred'],
#  (10, 'Lil Peep'): ['ghost boy',
#   'Broken Smile (My All)',
#   'Benz Truck (гелик)',
#   'Star Shopping',
#   "Leanin'"],
#  (10, 'Lil Peep, Lil Tracy'): ['Awful Things'],
#  (10, 'Lil Peep, XXXTENTACION'): ['Falling Down - Bonus Track'],
#  (10, 'Locals Only Sound, lentra'): ['Car'],
#  (10, 'MYRNE, Aviella'): ['Afterdark (feat. Aviella)'],
#  (10, 'Mac DeMarco'): ['My Kind of Woman'],
#  (10, 'Mac Miller'): ['I Can See'],
#  (10, 'Malice K'): ['Cherry'],
#  (10, 'Meltt'): ['Wash Over Me'],
#  (10, 'Moneybagg Yo, Kodak Black'): ['Lower Level (feat. Kodak Black)'],
#  (10, 'Moon Boots, Steven Klavier'): ['Tied Up'],
#  (10, 'Moonboy Inc.'): ['Losing My Mind'],
#  (10, 'Mutemath'): ['Used To'],
#  (10, 'Nate Traveller, Mills'): ['Airport'],
#  (10, 'Nirvana'): ['Come As You Are'],
#  (10, 'ODESZA, MARO'): ['Better Now (feat. MARO)'],
#  (10, 'Oliver Tree, Robin Schulz'): ['Miss You'],
#  (10, 'Orion Sun'): ['Coffee For Dinner'],
#  (10, 'Peach Pit'): ['Peach Pit', 'Peach Pit'],
#  (10, 'Plastic Picnic'): ['Bite'],
#  (10, 'Playboi Carti, Lil Uzi Vert'): ['Shoota (feat. Lil Uzi Vert)'],
#  (10, 'Plums'): ['Parking Lots'],
#  (10, 'PnB Rock'): ['Selfish'],
#  (10, 'Portugal. The Man'): ['Senseless', 'Live in the Moment'],
#  (10, 'Portugal. The Man, Fatlip'): ['Mr Lonely (feat. Fat Lip)'],
#  (10, 'Pretty Lights'): ['Rainbows & Waterfalls'],
#  (10, 'Pusha T, Rick Ross'): ['Hard Piano'],
#  (10, 'RKCB'): ['Vice'],
#  (10, 'RL Grime, Juelz'): ['Formula'],
#  (10, 'Ray Volpe, fknsyd'): ['Insane'],
#  (10, 'Reo Cragun'): ['Beam Me Up'],
#  (10, 'Rezz, Grabbitz'): ['Someone Else'],
#  (10, 'Rezz, Underoath'): ['Falling'],
#  (10, 'Rise Against'): ['Savior'],
#  (10, 'RÜFÜS DU SOL'): ['Nocturnal'],
#  (10, 'SAIAH'): ['MISFIT'],
#  (10, 'SPICE'): ["I DON'T WANNA DIE IN NEW YORK"],
#  (10, 'STRFKR'): ['Open Your Eyes'],
#  (10, 'Sarah and the Sundays'): ['Ruby Fields'],
#  (10, 'Seven Lions, Skyler Stonestreet'): ['Freesol'],
#  (10,
#   'Skan, Lox Chatterbox, M.I.M.E, Blvkstn'): ['Living Hell (feat. Blvkstn)'],
#  (10, 'Slatt Zy'): ['Angels Cry'],
#  (10, 'Slow Magic, ODESZA'): ['Waited 4 U - ODESZA Remix'],
#  (10, 'Sun Room'): ['Cadillac'],
#  (10, 'Super Whatevr'): ['melancholyism.'],
#  (10, 'Take/Five'): ['Mars'],
#  (10, 'Takeoff'): ['Infatuation'],
#  (10, 'Tash Sultana'): ['Salvation'],
#  (10, 'Teddy, Lil Tracy'): ['Girls Rule The World'],
#  (10,
#   'The Avalanches, Denzel Curry, Tricky, Sampa the Great'): ['Take Care In Your Dreaming'],
#  (10, 'The Black Keys'): ['In Time'],
#  (10, 'The Grinns'): ['Mona Lisa Lamborghini', 'Mona Lisa Lamborghini'],
#  (10,
#   'The Kid LAROI, Machine Gun Kelly'): ['F*CK YOU, GOODBYE (feat. Machine Gun Kelly)'],
#  (10, 'Travis Scott'): ['the ends'],
#  (10, 'TyFontaine'): ['Found'],
#  (10, 'Verzache, TREGS'): ['Hours'],
#  (10, 'Weston Estate'): ['Pears'],
#  (10, 'WiDE AWAKE'): ['HiGHER'],
#  (10, 'Win and Woo, Madnap'): ['Chasing Tail (Madnap Remix)'],
#  (10, 'XXXTENTACION, Trippie Redd'): ['Fuck Love (feat. Trippie Redd)'],
#  (10, 'ZHU, Tame Impala'): ['My Life'],
#  (10, 'bbno$, Diamond Pistols'): ['help herself'],
#  (10, 'ilo ilo'): ['come thru'],
#  (10, 'leon chang'): ['popcorn castle'],
#  (10, 'papa mbye'): ['ONLY RIGHT'],
#  (10, 'weird inside'): ['game point'],
#  (10, 'whiterosemoxie'): ['0006TeslaSpaceForce'],
#  (11, 'Carbon Based Lifeforms'): ['Interloper'],
#  (11,
#   'Circles Around The Sun, Neal Casal'): ["Gilbert's Groove (feat. Neal Casal)"],
#  (11, 'Crumb'): ['Locket'],
#  (11, 'Current Joys'): ['You Broke My Heart'],
#  (11, 'Teho'): ['Upside Down'],
#  (12, '$NOT, Teddi Jones'): ['BLUE MOON (feat. Teddi Jones)'],
#  (12, '99 Neighbors'): ['N. Michigan Gospel'],
#  (12, 'A$AP NAST, D33J'): ['Designer Boi'],
#  (12, 'Arden Jones'): ['SMILE', 'daisy'],
#  (12, 'Aries'): ['DITTO'],
#  (12, 'Cottonwood Firing Squad'): ['Mister Church'],
#  (12, 'Donald Ganim'): ['Bitty (1400/999)'],
#  (12, 'Dr. Dog'): ['Nellie'],
#  (12, 'Dybbukk, Dybbukk Covers'): ['Another Love - Sped Up'],
#  (12, 'Ethan Tasch'): ['Room'],
#  (12, 'Feng Suave'): ["Honey, There's No Time"],
#  (12, 'Frank Ocean'): ['In My Room'],
#  (12, 'French Cassettes'): ['Sunday Soda'],
#  (12, 'Froogle'): ['Way You Move'],
#  (12, 'Gracie Abrams'): ['Friend'],
#  (12, 'Hashir'): ['MOUNTAIN MAN'],
#  (12, 'Healy'): ['Deep Cuts'],
#  (12, 'Hotel Ugly'): ['Shut up My Moms Calling'],
#  (12, 'Indigo Girls'): ['Galileo'],
#  (12, 'JKER'): ['tonight'],
#  (12, 'JUICEB☮X, WES WAX'): ['Mushroom'],
#  (12, 'Jay Som'): ['Tenderness'],
#  (12,
#   'Johan Lenox, Lil Keed, Kota the Friend'): ['throwback thursday (feat. Lil Keed & KOTA The Friend) - chamber version'],
#  (12, 'June'): ['Circle of Life'],
#  (12, 'Kanye West'): ['Jonah', 'Closed On Sunday'],
#  (12, 'Kendrick Lamar'): ['Count Me Out', 'Count Me Out'],
#  (12, 'Kevin Abstract'): ['Peach'],
#  (12, 'King Geedorah'): ['Next Levels'],
#  (12, 'Kota the Friend'): ['Colorado'],
#  (12, 'Lil Peep, Lil Tracy'): ['white tee'],
#  (12, 'Lil Uzi Vert'): ['Erase Your Social'],
#  (12, 'Luchii, LUCKI'): ['X6'],
#  (12, 'Matty Wood$'): ['Sunday'],
#  (12, 'Medasin'): ['Home'],
#  (12, 'Men I Trust'): ['I Hope to Be Around',
#   'Say Can You Hear (Garage Session)',
#   'Show Me How'],
#  (12, 'Microwave'): ['keeping up'],
#  (12, 'Midwest Boyz, Ryder McLaughlin'): ['See It Through'],
#  (12, 'Milky Chance'): ['Sadnecessary'],
#  (12, 'Milo Korbenski'): ['All Hallows Grieve'],
#  (12,
#   'Nujabes, Cise Star, Akin Yai'): ['Feather (feat. Cise Starr & Akin from CYNE)'],
#  (12, 'Oshi'): ['silly boy'],
#  (12, 'Pritty, Kevin Bedford'): ['Imagine That'],
#  (12, 'RAC, Danny Dwyer'): ['MIA'],
#  (12, 'RAC, Instupendo'): ['Get A Life'],
#  (12, 'RIZ LA VIE'): ['Go Again'],
#  (12, 'Racoma'): ['Country'],
#  (12, 'Ralph Castelli, Whose Rules'): ['Hearts and Flowers'],
#  (12, 'Regina Spektor'): ['Hero'],
#  (12, 'Ritt Momney'): ['Young Adult'],
#  (12, 'SEBASTIAN PAUL'): ['LUST DRUNK'],
#  (12, 'SEE TAI'): ['Brother Sun'],
#  (12, 'Sam Amidon'): ['Juma Mountain'],
#  (12, 'Sky McCreery'): ['Insane'],
#  (12,
#   'Snøw, Rxseboy, Jack Cullen'): ['Spilled My Coffee (feat. Rxseboy & Jack Cullen)'],
#  (12, 'Steve Lacy'): ['Bad Habit', 'Bad Habit'],
#  (12, 'Still Woozy'): ['Rocky', 'Rocky', 'Cooks', 'Goodie Bag'],
#  (12, 'Strawberry Milk Cult'): ['Mustard'],
#  (12, 'Sun Room'): ['Crashed My Bike'],
#  (12, 'Swansea Skag'): ['I Heard You Bought a Gun'],
#  (12, 'The Brook & The Bluff'): ['Halfway Up'],
#  (12, 'Tobias Dray, Ben Chandler'): ["I Don't Mind (feat. Ben Chandler)"],
#  (12, 'Tycho Jones'): ['Level Head'],
#  (12, 'Vansire'): ['Kind of a Nice Time'],
#  (12, 'Video Age'): ['Pop Therapy'],
#  (12, 'Weston Estate'): ['Saturday Nights'],
#  (12, 'XXXTENTACION'): ['Hope', 'Everybody Dies In Their Nightmares'],
#  (12, 'Yot Club'): ['Fly Out West'],
#  (12, 'YoungBoy Never Broke Again'): ['Mr. Grim Reaper'],
#  (12, 'Yxngxr1'): ["don't leave too soon"],
#  (12, 'badmonsham'): ["Jumpin' in the Rain"],
#  (12, 'beabadoobee'): ['Tired'],
#  (12, 'iMAGiNARY OTHER, Chuuwee, i.F.'): ['Fly Away'],
#  (12, 'lentra'): ['upside down'],
#  (12, 'pizzagirl'): ['seabirds'],
#  (12, 'slowthai, Deb Never'): ['push (feat. Deb Never)'],
#  (12, 'tobi lou'): ['Endorphins'],
#  (12, 'tomcbumpz, Ivri, Souly Had'): ["we don't know a thing"],
#  (12, 'young friend'): ['PINCH ME'],
#  (12, 'yung van, Ouse'): ["I've Been So Numb Since You Left Me"],
#  (13, '070 Shake, Tame Impala'): ['Guilty Conscience - Tame Impala Remix'],
#  (13, 'Aaron May'): ['Ride'],
#  (13, 'Armani White'): ['stick up'],
#  (13, 'Benny The Butcher, J. Cole'): ["Johnny P's Caddy"],
#  (13, 'Carneyval, Armani White, Jackson Breit'): ['Jasmine'],
#  (13,
#   'Chamillionaire, Scarface, Killer Mike'): ['Reign Fall (feat. Scarface & Killer Mike)'],
#  (13, 'Cordae'): ['The Parables'],
#  (13, 'Cozz, J. Cole'): ['Zendaya (feat. J. Cole)'],
#  (13, 'Denzel Curry'): ['RICKY'],
#  (13, 'Dominic Fike'): ['Cancel Me'],
#  (13, 'Eminem, Juice WRLD'): ['Godzilla (feat. Juice WRLD)'],
#  (13, 'Future, Drake'): ['Life Is Good (feat. Drake)'],
#  (13, 'Goth Babe'): ['Topanga', 'Sunnnn', 'End Summer'],
#  (13, 'Gunna, Young Thug'): ['FAR (feat. Young Thug)'],
#  (13, 'JAY-Z'): ['The Story of O.J.'],
#  (13, 'JAY-Z, Beanie Sigel, Memphis Bleek, Freeway'): ['1-900-Hustler'],
#  (13, 'JID'): ['Off Da Zoinkys'],
#  (13, 'JID, 6LACK'): ['8701'],
#  (13, 'Joey Bada$$'): ['The Light'],
#  (13, 'Kanye West'): ['Off The Grid', 'Saint Pablo'],
#  (13, 'Kendrick Lamar, Sampha'): ['Father Time (feat. Sampha)',
#   'Father Time (feat. Sampha)'],
#  (13, 'Key Glock'): ['Mr. Glock'],
#  (13, 'Lil Peep'): ['fucked up'],
#  (13, 'Lonely God'): ['Marlboro Nights'],
#  (13, 'Mac Miller, Syd, Thundercat'): ['In the Morning'],
#  (13, 'Madvillain, Madlib, MF DOOM, MED'): ['Raid'],
#  (13, 'Nic D, Connor Price'): ['Gasoline'],
#  (13, 'Polo G'): ['21'],
#  (13, 'Pusha T, Tyler, The Creator'): ['Trouble On My Mind'],
#  (13, 'REASON'): ['Better Dayz'],
#  (13, 'Rakim'): ['How I Get Down'],
#  (13, 'Run The Jewels, Big Boi'): ['Banana Clipper (feat. Big Boi)'],
#  (13, 'SG Lewis, Master Peace'): ['Chemicals (feat. Master Peace) - Remix'],
#  (13,
#   'Spillage Village, JID, EARTHGANG, Hollywood JB'): ["Ea'alah (Family) (with JID & EARTHGANG feat. Hollywood JB)"],
#  (13, 'Stonebank, EMEL'): ['Coming On Strong'],
#  (13, 'Tyler, The Creator, Lil Wayne'): ['HOT WIND BLOWS (feat. Lil Wayne)'],
#  (13, 'Young Nudy, Future, 6LACK'): ['Zone 6 (Remix) (feat. Future & 6LACK)'],
#  (13, 'callmestevieray, Melkin'): ['Advanced - Remix'],
#  (14, '18veno'): ['Fuck Rap'],
#  (14, 'ADÉ, Lil Baby'): ['SOMETHING NEW (feat. Lil Baby)'],
#  (14, 'American Dead Cross'): ["Steamin' Tea and Malibu"],
#  (14, 'Aminé'): ['Charmander'],
#  (14, 'Angelo Mota'): ['Do Not Disturb'],
#  (14, 'Arden Jones'): ['without me'],
#  (14, 'Argonaut & Wasp'): ['Composure'],
#  (14, 'Aries'): ['HOME', 'SAYONARA', 'DEITY'],
#  (14, 'Arlo Parks'): ['Second Guessing'],
#  (14, 'Ayo River'): ['White Dress'],
#  (14, 'Baby Keem'): ['HONEST'],
#  (14,
#   'Big Gigantic, Kasbo, Angela McCluskey'): ['The Little Things (feat. Angela McCluskey) - Kasbo Remix'],
#  (14, 'Blood Cultures'): ['Keeps Bringing Me Back'],
#  (14, 'Briston Maroney'): ['Freeway'],
#  (14, 'Busu, ROLE MODEL'): ['100k coffin (ROLE MODEL Remix)'],
#  (14, 'Camera Obscura'): ['Dory Previn'],
#  (14, 'Clarence James'): ['Ronson Princess'],
#  (14, 'Coast Modern'): ['Hollow Life'],
#  (14, 'Danny Dwyer'): ['Losers'],
#  (14, 'Day Wave'): ['Potions'],
#  (14, 'Deb Never'): ['Sorry'],
#  (14, 'Derek Pope'): ['Future Kids of America'],
#  (14,
#   'Devault, Donnie Sloan, Ricky Ducati'): ['Nothing But You (feat. Donnie Sloan & Ricky Ducati)'],
#  (14, 'Dominic Fike'): ['Wurli'],
#  (14, 'Eastghost'): ["D'vocean"],
#  (14, 'Eric Clapton'): ['Cocaine'],
#  (14, 'Eryn Martin, Guapdad 4000'): ['Ball - Remix'],
#  (14, 'Ethan Tasch'): ['Face Again'],
#  (14, 'Evann McIntosh'): ['WIYULD'],
#  (14, 'Fantasy Camp'): ['bug bite'],
#  (14, 'Frances Forever'): ['space girl'],
#  (14, 'Giraffage, Japanese Breakfast'): ['Maybes'],
#  (14, 'Glass Animals'): ['Heat Waves'],
#  (14, 'Goth Babe'): ['Imaginationcy',
#   'Moments / Tides',
#   'Moments / Tides',
#   'Laurelhurst',
#   'The Trees',
#   'Sometimes'],
#  (14, 'Grabbitz'): ['King / Ghost In A Song'],
#  (14, 'Hether'): ['Twinkle', 'Twinkle'],
#  (14, 'Hippo Campus'): ['Bambi'],
#  (14, 'ILLENIUM, Emilie Brandt'): ['Lost'],
#  (14, 'JAWNY'): ['Trigger Of Love'],
#  (14, 'JOY.'): ['Smoke Too Much'],
#  (14, 'Jimi Hendrix'): ['The Wind Cries Mary'],
#  (14, 'John Eatherly'): ['Burnout'],
#  (14, 'Jonah Zed'): ['happy now'],
#  (14, 'Juice WRLD'): ['Stay High'],
#  (14, 'JuiceDaWrld'): ['Dirty Soda'],
#  (14, 'KAMAUU'): ['Far Rockaway'],
#  (14, 'Kasbo, Keiynan Lonsdale'): ['Lay It On Me (feat. Keiynan Lonsdale)'],
#  (14, 'Kodak Black'): ['No Codefendant'],
#  (14, 'Kygo, Maty Noyes'): ['Stay (feat. Maty Noyes)'],
#  (14, 'Labrinth'): ['Formula'],
#  (14, 'Led Zeppelin'): ['Over the Hills and Far Away - 1990 Remaster'],
#  (14, 'Lil Bo Weep, ELHIXIR'): ['not ok but its ok'],
#  (14, 'Lil Peep'): ['driveway',
#   'skyscrapers (love now, cry later)',
#   'Life is Beautiful'],
#  (14, 'Lil Tracy'): ['Halo'],
#  (14, 'Lil Uzi Vert'): ['Scott and Ramona'],
#  (14, 'Louis The Child, Wafia'): ['Better Not (with Wafia)'],
#  (14, 'Marcus King'): ['The Well'],
#  (14, "Marlin's Dreaming"): ['Mixed Up and Confused'],
#  (14,
#   'Melo Makes Music, Ju, Tatiana Hazel'): ["Murphy's Law (feat. Ju & Tatiana Hazel)"],
#  (14, 'Mishaal Tamer, Teqkoi, Ondi Vil'): ['Addicted'],
#  (14, 'Molokai'): ["She Don't Wear the Same Clothes"],
#  (14, 'Morray'): ['Low Key'],
#  (14, 'Mr.Kitty'): ['After Dark'],
#  (14, 'Mt. Joy'): ['Rearrange Us'],
#  (14, 'Mustard Service'): ['Taking Up Space'],
#  (14, 'Nick Leng'): ['Playing with Fire', 'Playing with Fire'],
#  (14,
#   'ODESZA, WYNNE, Mansionair'): ['Line Of Sight (feat. WYNNE & Mansionair)'],
#  (14, 'On Planets'): ["Don't Think So Hard"],
#  (14, 'Oshi'): ['My Girl'],
#  (14, 'Palace'): ['Bitter'],
#  (14, 'Peach Pit'): ['Black Licorice'],
#  (14, 'Peach Tree Rascals'): ['Mariposa'],
#  (14, 'Phish'): ['Dirt'],
#  (14, 'Polo & Pan'): ['Aqualand'],
#  (14, 'Poppy Tears, 9tails'): ['Healthy Relief'],
#  (14, 'Porter Robinson'): ['Trying to Feel Alive'],
#  (14, 'Porter Robinson, Totally Enormous Extinct Dinosaurs'): ['Unfold'],
#  (14, 'Prblm Chld, Emerald Lake'): ['14U'],
#  (14, 'Prelow'): ['Back When'],
#  (14, 'Prentiss'): ['October'],
#  (14, 'RL Grime, Daya'): ['I Wanna Know'],
#  (14, 'ROLE MODEL'): ['girl in new york'],
#  (14, 'Radiohead'): ['No Surprises'],
#  (14, 'Rainbow Kitten Surprise'): ["All's Well That Ends"],
#  (14, 'Rex Orange County, Marco McKinnis'): ['Nothing'],
#  (14, 'Rezz, Metric'): ['Paper Walls'],
#  (14, 'Rich Brian'): ['Long Run'],
#  (14, 'Rick Ross, Kanye West, Big Sean'): ['Sanctified'],
#  (14, 'Roddy Ricch'): ['Down Below'],
#  (14, 'Ruel'): ['Painkiller'],
#  (14, 'SAIAH'): ['Cold'],
#  (14, 'SAINt JHN'): ['I Heard You Got Too Litt Last Night'],
#  (14, 'SPIRIT LINK, Blxckbxrd'): ['All In My Head'],
#  (14, 'SWMRS'): ['Lose It'],
#  (14, 'Sarah Barrios'): ['Mourn The Living'],
#  (14, 'Sen Morimoto'): ['Woof'],
#  (14, 'Seno, Dominic Fike'): ['Elizabeth (feat. Dominic Fike)'],
#  (14, 'Skizzy Mars'): ['Comb'],
#  (14, 'Slow Pulp'): ['Montana', 'High'],
#  (14, 'Small Forward'): ['Imagine So'],
#  (14, 'Sure Sure'): ['Funky Galileo'],
#  (14, 'Swan Lingo'): ['Drama Queen'],
#  (14, 'Terry Presume'): ['None of This Alone'],
#  (14, 'The Kid LAROI'): ['SO DONE'],
#  (14, 'The Neighbourhood'): ['Cherry Flavoured'],
#  (14, 'The Neighbourhood Watch'): ['A A'],
#  (14, 'The Ninetys'): ['All Saints'],
#  (14, 'The Palms'): ['Human Condition'],
#  (14, 'The Walters'): ['I Love You So'],
#  (14, 'Thekidszn'): ['Leave Me Alone'],
#  (14, 'Tokyo Police Club'): ['Hang Your Heart'],
#  (14, 'Trippie Redd, Coi Leray'): ['Everything BoZ'],
#  (14, 'Tutara Peak, Aether, Zes, Lilia, Grand Pavilion'): ['Daydream'],
#  (14, 'UnoTheActivist, Travis Barker'): ['Paper'],
#  (14, 'Vince Staples'): ['Norf Norf'],
#  (14, 'Zaytoven, Future'): ['Mo Reala'],
#  (14, 'Zubin, YAWNS'): ['Perfect Hell'],
#  (14, 'charlieonnafriday'): ['Enough'],
#  (14, 'diveliner'): ['F150', 'teacher'],
#  (14, 'faang'): ['Satellites'],
#  (14, 'iann dior'): ['emotions'],
#  (14, 'iann dior, Trippie Redd'): ['gone girl'],
#  (14, 'maxime.'): ['\u200etelephone \u200ewires'],
#  (14, 'pluko'): ['pink.'],
#  (14, 'sleep well.'): ['I Am the One That I Love'],
#  (15, '100 gecs'): ['toothless', 'came to my show'],
#  (15, 'AUDREY NUNA, DJ Snake'): ['damn Right Pt. 2'],
#  (15, 'Ages and Ages'): ['Needle and Thread'],
#  (15, 'Amtrac'): ['Stratego'],
#  (15, 'Anoyd'): ['World On Silent'],
#  (15, 'Aries'): ['SANTA MONICA'],
#  (15, 'Arlie'): ['Big Fat Mouth'],
#  (15, 'Aspen Forest'): ['PIPE DREAMS'],
#  (15, 'Baby Keem'): ['16'],
#  (15, 'Bakar'): ['1st Time'],
#  (15, 'Baseball Game'): ['Woman'],
#  (15, 'Bazzi'): ['Young & Alive'],
#  (15, 'Beach Bunny'): ['Weeds'],
#  (15,
#   'Ben Folds, Regina Spektor'): ["You Don't Know Me (feat. Regina Spektor)"],
#  (15, 'Bickle'): ['Naked'],
#  (15, 'COIN'): ['I Think I Met You In A Dream',
#   'Chapstick',
#   "I Don't Wanna Dance"],
#  (15, 'Carter Vail'): ['Melatonin'],
#  (15, 'Caye'): ['Ear Candy'],
#  (15, 'Childish Gambino'): ['Retro [ROUGH]'],
#  (15, 'Clairo'): ['Bags'],
#  (15, 'Cream'): ['Sunshine Of Your Love'],
#  (15, 'Creedence Clearwater Revival'): ['Have You Ever Seen The Rain',
#   'Down On The Corner'],
#  (15, 'Current Joys'): ['Kids'],
#  (15, 'Dayglow'): ['Nicknames', 'Nicknames', 'Close To You'],
#  (15, 'Djo'): ['Personal Lies'],
#  (15, 'Don Toliver, Quavo, Offset'): ['HAD ENOUGH (feat. Quavo & Offset)'],
#  (15, 'Drake, Lil Durk'): ['Laugh Now Cry Later (feat. Lil Durk)'],
#  (15, 'Duke Dumont, Shaun Ross'): ['Red Light Green Light'],
#  (15, 'Elohim, Snakehips'): ['Good Day Bad Day - Snakehips Remix'],
#  (15, 'ElyOtto'): ['SugarCrash!'],
#  (15, 'Faze Wave, Groove Inn'): ['The Game'],
#  (15, 'Forever Golden'): ['Menace'],
#  (15, "Goth Babe, Dre'es"): ['Blue Skies'],
#  (15, 'Gus Dapperton'): ['Post Humorous'],
#  (15, 'Humans'): ['Beggin'],
#  (15, 'Inner Wave'): ['Mushroom'],
#  (15,
#   'Internet Money, Trippie Redd, Diplo, Juice WRLD'): ['Blastoff (feat. Juice Wrld & Trippie Redd)', 'Blastoff', 'Blastoff (feat. Juice Wrld & Trippie Redd)', 'Blastoff (feat. Juice Wrld & Trippie Redd)'],
#  (15, 'Jack Kays'): ['MORBID MIND'],
#  (15, 'Jaden'): ['Cabin Fever'],
#  (15, 'Jelani Aryeh'): ['Marigold', 'Stella Brown'],
#  (15, 'Juice WRLD'): ['Empty', 'Robbery'],
#  (15, 'K. Roosevelt'): ['Blinding My Vision'],
#  (15, 'KIDS SEE GHOSTS, Yasiin Bey'): ['Kids See Ghosts'],
#  (15, 'Kendrick Lamar'): ['N95', 'N95'],
#  (15, 'Kid Cudi'): ['Leader Of The Delinquents'],
#  (15, "Kota the Friend, Hello O'shay, Alex Banin"): ['Long Beach'],
#  (15, 'Kyle Dion'): ['Brown'],
#  ...}

# %%
def create_playlist_chart(cluster_name):
    cluster_df = df[df['cluster_grouping'] == cluster_name]
    playlist_table = cluster_df[['artist', 'song_names']]
    playlist_table.index = range(1, len(playlist_table)+1)
    return playlist_table
